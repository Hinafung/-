# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import os
os.getcwd()
# Out:
# '/Users/hina'

# %%
path='/Users/hina/Desktop/coding/tobeadatascientist/msg/Sales interface error population'
os.chdir(path)
os.getcwd()
os.listdir()
# Out:
# ['WAL MART AND SAM SUSPENDED STORES FOR CN (23).msg',
#  'WAL MART AND SAM SUSPENDED STORES FOR CN (145).msg',
#  'WAL MART AND SAM SUSPENDED STORES FOR CN (7).msg',
#  'WAL MART AND SAM SUSPENDED STORES FOR CN (74).msg',
#  'WAL MART AND SAM SUSPENDED STORES FOR CN (112).msg',
#  'WAL MART AND SAM SUSPENDED STORES FOR CN (62).msg',
#  'WAL MART AND SAM SUSPENDED STORES FOR CN (104).msg',
#  'WAL MART AND SAM SUSPENDED STORES FOR CN (35).msg',
#  'WAL MART AND SAM SUSPENDED STORES FOR CN (153).msg',
#  'WAL MART AND SAM SUSPENDED STORES FOR CN (128).msg',
#  'WAL MART AND SAM SUSPENDED STORES FOR CN (256).msg',
#  'WAL MART AND SAM SUSPENDED STORES FOR CN (19).msg',
#  'WAL MART AND SAM SUSPENDED STORES FOR CN (190).msg',
#  'WAL MART AND SAM SUSPENDED STORES FOR CN (240).msg',
#  'WAL MART AND SAM SUSPENDED STORES FOR CN (169).msg',
#  'WAL MART AND SAM SUSPENDED STORES FOR CN (186).msg',
#  'WAL MART AND SAM SUSPENDED STORES FOR CN (58).msg',
# ...

# %%
import extract_msg
for name in os.listdir(path):
    msg=extract_msg.Message(path+'/'+name)
    body=msg.body
    with open('/Users/hina/Desktop/coding/tobeadatascientist/msg/Sales interface error population/msg.txt','a',encoding='utf-8') as f:
        f.writelines(body)

# %%
path='/Users/hina/Desktop/coding/tobeadatascientist/msg/Sales interface error population'
print('filenum:',len([lists for lists in os.listdir(path) if os.path.isfile(os.path.join(path, lists))]))
# Out:
# filenum: 248
